# %%
import sys
import math
from gurobipy import *
import numpy
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
alpha = 0.0001
pi = 0.5
T = 20
N = 10000

def impact(x,alpha,pi):
    return 1-alpha*x**pi

def deri_impact(x,alpha,pi):
    return -alpha*pi*x**(pi-1)

def gradcomp(n, gradient,x,alpha,pi):
    #part1 
    impact_series = np.cumprod(impact(x,alpha,pi))
    part1 = impact_series

    #part2
    #the rest multiplied terms
    intermediate_term1 = (impact_series*x)[::-1]
    term1 = np.cumsum(intermediate_term1)[::-1]/impact(x,alpha,pi)
    #derivative of impact functions
    term2 = deri_impact(x,alpha,pi)
    part2 = np.nan_to_num(term1) * np.nan_to_num(term2)
    gradient = part1 + part2
    return gradient

def myfunction(x):
    return (np.dot(impact(x,alpha,pi).cumprod(),x))

def line_search(x ,y):
    index = np.linspace(0,1,10000)
    change = (index[:,np.newaxis] * y)
    x_matrix = np.tile(x, (10000,1))
    sum_change = pd.DataFrame(x_matrix + change)
    best_size = sum_change.apply(myfunction, axis=1).argmax()
    return 1/10000 * best_size

def loop(n,xsol,row1):
    x = np.zeros(n)
    gradient = numpy.zeros(n)
    slacks = 0
    for j in range(n):
        x[j] = xsol[j]

    maxits = 100
    for itcount in range(maxits):
        val = myfunction(x)
        gradient = gradcomp(n, gradient,x,alpha,pi)
        print ("hello, value = ", val)
        compute_slacks(n, row1, x, slacks)
        y = steplp(n, row1, x, slacks, gradient)
        step_size = line_search(x,y)
        print('step_size:', step_size)
        
        val_1 = myfunction(x)                        #stopping condition
        x = x + step_size * y
        val_2 = myfunction(x)
        if val_2 - val_1 < 0.000000001:
            print('optimal achieved at ', val)
            print('optimal selling: ', x)
            return            
        print ('x:  ', x)

def compute_slacks(n, row1, x, slacks):
    slacks = N - np.sum(x)

    
def steplp(n, row1, x, slacks, gradient):
    m = Model("feasible")
    m.ModelSense = 1 #minimize
    #create variables and put into a dictionary
    deltavar = {}
    for j in range(n):
        deltavar[j] = m.addVar(lb = -x[j], ub = N-x[j], obj = -gradient[j], vtype = GRB.CONTINUOUS, name = "delta_"+str(j+1))

    # Update model to integrate new variables
    m.update()    
    #add first constraint
    xpr = LinExpr()
    for j in range(n):
        xpr += row1[j]*deltavar[j]
    m.addConstr(xpr == slacks, name="const1")        
   
    m.write("step.lp")
    m.optimize()

    code = "optimal"

    if m.status == GRB.status.INF_OR_UNBD:
        print('->LP infeasible or unbounded\n')
        code = "inf_or_unbd"
    if m.status == GRB.status.UNBOUNDED:
        print('->LP unbounded\n')
        code = "unbd"
    if m.status == GRB.status.INFEASIBLE:
        print('->LP infeasible\n')
        code = "infeas"


    print(" -> LP optimal, value = %g\n" %(m.objval))

    deltasol = numpy.zeros(n)
    for j in range(n):
        #print ("%s = %g" %(deltavar[j].varname, deltavar[j].x))
        deltasol[j] = deltavar[j].x

    print ('deltasol:', deltasol)

    return deltasol

def run():
    n = T
    row1 = numpy.repeat(1,n)
    feasible = np.repeat(N/T, T)
    #feasible = np.zeros(T)
    #feasible[0] = N
    code, xsol = 'feasible', feasible

    print ("initial feasible solution = ")
    print(xsol)

    loop(n,xsol,row1)

if __name__ == '__main__':
    run()
# Out:
# initial feasible solution =
# [500. 500. 500. 500. 500. 500. 500. 500. 500. 500. 500. 500. 500. 500.
#  500. 500. 500. 500. 500. 500.]
# hello, value =  9768.504658048427
# Optimize a model with 1 rows, 20 columns and 20 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e+02, 1e+04]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 1 rows and 20 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.0433299e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds
# Optimal objective -1.043329874e+02
#  -> LP optimal, value = -104.333
#
# deltasol: [9500. -500. -500. -500. -500. -500. -500. -500. -500. -500. -500. -500.
#  -500. -500. -500. -500. -500. -500. -500. -500.]
# step_size: 0.9766
# x:   [9777.7   11.7   11.7   11.7   11.7   11.7   11.7   11.7   11.7   11.7
#    11.7   11.7   11.7   11.7   11.7   11.7   11.7   11.7   11.7   11.7]
# hello, value =  9900.36642550803
# Optimize a model with 1 rows, 20 columns and 20 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+01, 1e+04]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 1 rows and 20 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.5102056e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds
# Optimal objective -1.510205553e+01
#  -> LP optimal, value = -15.1021
#
# deltasol: [-9777.7  9988.3   -11.7   -11.7   -11.7   -11.7   -11.7   -11.7   -11.7
#    -11.7   -11.7   -11.7   -11.7   -11.7   -11.7   -11.7   -11.7   -11.7
#    -11.7   -11.7]
# step_size: 0.12050000000000001
# x:   [8599.48715 1215.29015   10.29015   10.29015   10.29015   10.29015
#    10.29015   10.29015   10.29015   10.29015   10.29015   10.29015
#    10.29015   10.29015   10.29015   10.29015   10.29015   10.29015
#    10.29015   10.29015]
# hello, value =  9901.873267602747
# Optimize a model with 1 rows, 20 columns and 20 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+01, 1e+04]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 1 rows and 20 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -5.4131708e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds
# Optimal objective -5.413170823e-01
#  -> LP optimal, value = -0.541317
#
# deltasol: [ 1400.51285 -1215.29015   -10.29015   -10.29015   -10.29015   -10.29015
#    -10.29015   -10.29015   -10.29015   -10.29015   -10.29015   -10.29015
#    -10.29015   -10.29015   -10.29015   -10.29015   -10.29015   -10.29015
#    -10.29015   -10.29015]
# step_size: 0.14980000000000002
# x:   [8.80928397e+03 1.03323969e+03 8.74868553e+00 8.74868553e+00
#  8.74868553e+00 8.74868553e+00 8.74868553e+00 8.74868553e+00
#  8.74868553e+00 8.74868553e+00 8.74868553e+00 8.74868553e+00
#  8.74868553e+00 8.74868553e+00 8.74868553e+00 8.74868553e+00
#  8.74868553e+00 8.74868553e+00 8.74868553e+00 8.74868553e+00]
# hello, value =  9901.91449125802
# Optimize a model with 1 rows, 20 columns and 20 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [9e+00, 1e+04]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 1 rows and 20 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -3.0661134e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds
# Optimal objective -3.066113394e+00
#  -> LP optimal, value = -3.06611
#
# deltasol: [-8.80928397e+03  8.96676031e+03 -8.74868553e+00 -8.74868553e+00
#  -8.74868553e+00 -8.74868553e+00 -8.74868553e+00 -8.74868553e+00
#  -8.74868553e+00 -8.74868553e+00 -8.74868553e+00 -8.74868553e+00
#  -8.74868553e+00 -8.74868553e+00 -8.74868553e+00 -8.74868553e+00
#  -8.74868553e+00 -8.74868553e+00 -8.74868553e+00 -8.74868553e+00]
# step_size: 0.021500000000000002
# x:   [8.61988437e+03 1.22602503e+03 8.56058879e+00 8.56058879e+00
#  8.56058879e+00 8.56058879e+00 8.56058879e+00 8.56058879e+00
#  8.56058879e+00 8.56058879e+00 8.56058879e+00 8.56058879e+00
#  8.56058879e+00 8.56058879e+00 8.56058879e+00 8.56058879e+00
#  8.56058879e+00 8.56058879e+00 8.56058879e+00 8.56058879e+00]
# hello, value =  9901.946967301683
# Optimize a model with 1 rows, 20 columns and 20 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [9e+00, 1e+04]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 1 rows and 20 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -3.8487021e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds
# Optimal objective -3.848702139e-01
#  -> LP optimal, value = -0.38487
#
# deltasol: [ 1380.11563053 -1226.02503229    -8.56058879    -8.56058879
#     -8.56058879    -8.56058879    -8.56058879    -8.56058879
#     -8.56058879    -8.56058879    -8.56058879    -8.56058879
#     -8.56058879    -8.56058879    -8.56058879    -8.56058879
#     -8.56058879    -8.56058879    -8.56058879    -8.56058879]
# step_size: 0.11170000000000001
# x:   [8.77404329e+03 1.08907804e+03 7.60437102e+00 7.60437102e+00
#  7.60437102e+00 7.60437102e+00 7.60437102e+00 7.60437102e+00
#  7.60437102e+00 7.60437102e+00 7.60437102e+00 7.60437102e+00
#  7.60437102e+00 7.60437102e+00 7.60437102e+00 7.60437102e+00
#  7.60437102e+00 7.60437102e+00 7.60437102e+00 7.60437102e+00]
# hello, value =  9901.968731254352
# Optimize a model with 1 rows, 20 columns and 20 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [8e+00, 1e+04]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 1 rows and 20 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.2684220e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds
# Optimal objective -2.268421978e+00
#  -> LP optimal, value = -2.26842
#
# deltasol: [-8.77404329e+03  8.91092196e+03 -7.60437102e+00 -7.60437102e+00
#  -7.60437102e+00 -7.60437102e+00 -7.60437102e+00 -7.60437102e+00
#  -7.60437102e+00 -7.60437102e+00 -7.60437102e+00 -7.60437102e+00
#  -7.60437102e+00 -7.60437102e+00 -7.60437102e+00 -7.60437102e+00
#  -7.60437102e+00 -7.60437102e+00 -7.60437102e+00 -7.60437102e+00]
# step_size: 0.0162
# x:   [8.63190378e+03 1.23343497e+03 7.48118021e+00 7.48118021e+00
#  7.48118021e+00 7.48118021e+00 7.48118021e+00 7.48118021e+00
#  7.48118021e+00 7.48118021e+00 7.48118021e+00 7.48118021e+00
#  7.48118021e+00 7.48118021e+00 7.48118021e+00 7.48118021e+00
#  7.48118021e+00 7.48118021e+00 7.48118021e+00 7.48118021e+00]
# hello, value =  9901.986904298745
# Optimize a model with 1 rows, 20 columns and 20 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [7e+00, 1e+04]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 1 rows and 20 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.9786712e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds
# Optimal objective -2.978671210e-01
#  -> LP optimal, value = -0.297867
#
# deltasol: [ 1368.09621582 -1233.434972      -7.48118021    -7.48118021
#     -7.48118021    -7.48118021    -7.48118021    -7.48118021
#     -7.48118021    -7.48118021    -7.48118021    -7.48118021
#     -7.48118021    -7.48118021    -7.48118021    -7.48118021
#     -7.48118021    -7.48118021    -7.48118021    -7.48118021]
# step_size: 0.0889
# x:   [8.75352754e+03 1.12378260e+03 6.81610329e+00 6.81610329e+00
#  6.81610329e+00 6.81610329e+00 6.81610329e+00 6.81610329e+00
#  6.81610329e+00 6.81610329e+00 6.81610329e+00 6.81610329e+00
#  6.81610329e+00 6.81610329e+00 6.81610329e+00 6.81610329e+00
#  6.81610329e+00 6.81610329e+00 6.81610329e+00 6.81610329e+00]
# hello, value =  9902.000275903967
# Optimize a model with 1 rows, 20 columns and 20 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [7e+00, 1e+04]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 1 rows and 20 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.7954365e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds
# Optimal objective -1.795436506e+00
#  -> LP optimal, value = -1.79544
#
# deltasol: [-8.75352754e+03  8.87621740e+03 -6.81610329e+00 -6.81610329e+00
#  -6.81610329e+00 -6.81610329e+00 -6.81610329e+00 -6.81610329e+00
#  -6.81610329e+00 -6.81610329e+00 -6.81610329e+00 -6.81610329e+00
#  -6.81610329e+00 -6.81610329e+00 -6.81610329e+00 -6.81610329e+00
#  -6.81610329e+00 -6.81610329e+00 -6.81610329e+00 -6.81610329e+00]
# step_size: 0.013000000000000001
# x:   [8.63973168e+03 1.23917343e+03 6.72749395e+00 6.72749395e+00
#  6.72749395e+00 6.72749395e+00 6.72749395e+00 6.72749395e+00
#  6.72749395e+00 6.72749395e+00 6.72749395e+00 6.72749395e+00
#  6.72749395e+00 6.72749395e+00 6.72749395e+00 6.72749395e+00
#  6.72749395e+00 6.72749395e+00 6.72749395e+00 6.72749395e+00]
# hello, value =  9902.011811238672
# Optimize a model with 1 rows, 20 columns and 20 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [7e+00, 1e+04]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 1 rows and 20 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.4284097e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds
# Optimal objective -2.428409749e-01
#  -> LP optimal, value = -0.242841
#
# deltasol: [ 1360.26832023 -1239.17342915    -6.72749395    -6.72749395
#     -6.72749395    -6.72749395    -6.72749395    -6.72749395
#     -6.72749395    -6.72749395    -6.72749395    -6.72749395
#     -6.72749395    -6.72749395    -6.72749395    -6.72749395
#     -6.72749395    -6.72749395    -6.72749395    -6.72749395]
# step_size: 0.0738
# x:   [8.74011948e+03 1.14772243e+03 6.23100490e+00 6.23100490e+00
#  6.23100490e+00 6.23100490e+00 6.23100490e+00 6.23100490e+00
#  6.23100490e+00 6.23100490e+00 6.23100490e+00 6.23100490e+00
#  6.23100490e+00 6.23100490e+00 6.23100490e+00 6.23100490e+00
#  6.23100490e+00 6.23100490e+00 6.23100490e+00 6.23100490e+00]
# hello, value =  9902.020846966841
# Optimize a model with 1 rows, 20 columns and 20 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [6e+00, 1e+04]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 1 rows and 20 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.4803446e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds
# Optimal objective -1.480344592e+00
#  -> LP optimal, value = -1.48034
#
# deltasol: [-8.74011948e+03  8.85227757e+03 -6.23100490e+00 -6.23100490e+00
#  -6.23100490e+00 -6.23100490e+00 -6.23100490e+00 -6.23100490e+00
#  -6.23100490e+00 -6.23100490e+00 -6.23100490e+00 -6.23100490e+00
#  -6.23100490e+00 -6.23100490e+00 -6.23100490e+00 -6.23100490e+00
#  -6.23100490e+00 -6.23100490e+00 -6.23100490e+00 -6.23100490e+00]
# step_size: 0.0108
# x:   [8.64572619e+03 1.24332703e+03 6.16371004e+00 6.16371004e+00
#  6.16371004e+00 6.16371004e+00 6.16371004e+00 6.16371004e+00
#  6.16371004e+00 6.16371004e+00 6.16371004e+00 6.16371004e+00
#  6.16371004e+00 6.16371004e+00 6.16371004e+00 6.16371004e+00
#  6.16371004e+00 6.16371004e+00 6.16371004e+00 6.16371004e+00]
# hello, value =  9902.028757915754
# Optimize a model with 1 rows, 20 columns and 20 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [6e+00, 1e+04]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 1 rows and 20 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.0387635e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds
# Optimal objective -2.038763520e-01
#  -> LP optimal, value = -0.203876
#
# deltasol: [ 1354.2738086  -1243.32702783    -6.16371004    -6.16371004
#     -6.16371004    -6.16371004    -6.16371004    -6.16371004
#     -6.16371004    -6.16371004    -6.16371004    -6.16371004
#     -6.16371004    -6.16371004    -6.16371004    -6.16371004
#     -6.16371004    -6.16371004    -6.16371004    -6.16371004]
# step_size: 0.06280000000000001
# x:   [8.73077459e+03 1.16524609e+03 5.77662905e+00 5.77662905e+00
#  5.77662905e+00 5.77662905e+00 5.77662905e+00 5.77662905e+00
#  5.77662905e+00 5.77662905e+00 5.77662905e+00 5.77662905e+00
#  5.77662905e+00 5.77662905e+00 5.77662905e+00 5.77662905e+00
#  5.77662905e+00 5.77662905e+00 5.77662905e+00 5.77662905e+00]
# hello, value =  9902.035204518557
# Optimize a model with 1 rows, 20 columns and 20 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [6e+00, 1e+04]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 1 rows and 20 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.2562031e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds
# Optimal objective -1.256203134e+00
#  -> LP optimal, value = -1.2562
#
# deltasol: [-8.73077459e+03  8.83475391e+03 -5.77662905e+00 -5.77662905e+00
#  -5.77662905e+00 -5.77662905e+00 -5.77662905e+00 -5.77662905e+00
#  -5.77662905e+00 -5.77662905e+00 -5.77662905e+00 -5.77662905e+00
#  -5.77662905e+00 -5.77662905e+00 -5.77662905e+00 -5.77662905e+00
#  -5.77662905e+00 -5.77662905e+00 -5.77662905e+00 -5.77662905e+00]
# step_size: 0.0092
# x:   [8.65045146e+03 1.24652583e+03 5.72348406e+00 5.72348406e+00
#  5.72348406e+00 5.72348406e+00 5.72348406e+00 5.72348406e+00
#  5.72348406e+00 5.72348406e+00 5.72348406e+00 5.72348406e+00
#  5.72348406e+00 5.72348406e+00 5.72348406e+00 5.72348406e+00
#  5.72348406e+00 5.72348406e+00 5.72348406e+00 5.72348406e+00]
# hello, value =  9902.040936950689
# Optimize a model with 1 rows, 20 columns and 20 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [6e+00, 1e+04]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 1 rows and 20 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.7492172e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds
# Optimal objective -1.749217199e-01
#  -> LP optimal, value = -0.174922
#
# deltasol: [ 1349.54853962 -1246.52582645    -5.72348406    -5.72348406
#     -5.72348406    -5.72348406    -5.72348406    -5.72348406
#     -5.72348406    -5.72348406    -5.72348406    -5.72348406
#     -5.72348406    -5.72348406    -5.72348406    -5.72348406
#     -5.72348406    -5.72348406    -5.72348406    -5.72348406]
# step_size: 0.054400000000000004
# x:   [8.72386690e+03 1.17871482e+03 5.41212653e+00 5.41212653e+00
#  5.41212653e+00 5.41212653e+00 5.41212653e+00 5.41212653e+00
#  5.41212653e+00 5.41212653e+00 5.41212653e+00 5.41212653e+00
#  5.41212653e+00 5.41212653e+00 5.41212653e+00 5.41212653e+00
#  5.41212653e+00 5.41212653e+00 5.41212653e+00 5.41212653e+00]
# hello, value =  9902.045726793896
# Optimize a model with 1 rows, 20 columns and 20 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e+00, 1e+04]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 1 rows and 20 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.0877835e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds
# Optimal objective -1.087783530e+00
#  -> LP optimal, value = -1.08778
#
# deltasol: [-8.72386690e+03  8.82128518e+03 -5.41212653e+00 -5.41212653e+00
#  -5.41212653e+00 -5.41212653e+00 -5.41212653e+00 -5.41212653e+00
#  -5.41212653e+00 -5.41212653e+00 -5.41212653e+00 -5.41212653e+00
#  -5.41212653e+00 -5.41212653e+00 -5.41212653e+00 -5.41212653e+00
#  -5.41212653e+00 -5.41212653e+00 -5.41212653e+00 -5.41212653e+00]
# step_size: 0.008
# x:   [8.65407597e+03 1.24928510e+03 5.36882952e+00 5.36882952e+00
#  5.36882952e+00 5.36882952e+00 5.36882952e+00 5.36882952e+00
#  5.36882952e+00 5.36882952e+00 5.36882952e+00 5.36882952e+00
#  5.36882952e+00 5.36882952e+00 5.36882952e+00 5.36882952e+00
#  5.36882952e+00 5.36882952e+00 5.36882952e+00 5.36882952e+00]
# hello, value =  9902.05004542283
# Optimize a model with 1 rows, 20 columns and 20 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e+00, 1e+04]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 1 rows and 20 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.5305935e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds
# Optimal objective -1.530593479e-01
#  -> LP optimal, value = -0.153059
#
# deltasol: [ 1345.92403427 -1249.28510292    -5.36882952    -5.36882952
#     -5.36882952    -5.36882952    -5.36882952    -5.36882952
#     -5.36882952    -5.36882952    -5.36882952    -5.36882952
#     -5.36882952    -5.36882952    -5.36882952    -5.36882952
#     -5.36882952    -5.36882952    -5.36882952    -5.36882952]
# step_size: 0.048
# x:   [8.71868032e+03 1.18931942e+03 5.11112570e+00 5.11112570e+00
#  5.11112570e+00 5.11112570e+00 5.11112570e+00 5.11112570e+00
#  5.11112570e+00 5.11112570e+00 5.11112570e+00 5.11112570e+00
#  5.11112570e+00 5.11112570e+00 5.11112570e+00 5.11112570e+00
#  5.11112570e+00 5.11112570e+00 5.11112570e+00 5.11112570e+00]
# hello, value =  9902.05373895651
# Optimize a model with 1 rows, 20 columns and 20 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e+00, 1e+04]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 1 rows and 20 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -9.5819294e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds
# Optimal objective -9.581929450e-01
#  -> LP optimal, value = -0.958193
#
# deltasol: [-8.71868032e+03  8.81068058e+03 -5.11112570e+00 -5.11112570e+00
#  -5.11112570e+00 -5.11112570e+00 -5.11112570e+00 -5.11112570e+00
#  -5.11112570e+00 -5.11112570e+00 -5.11112570e+00 -5.11112570e+00
#  -5.11112570e+00 -5.11112570e+00 -5.11112570e+00 -5.11112570e+00
#  -5.11112570e+00 -5.11112570e+00 -5.11112570e+00 -5.11112570e+00]
# step_size: 0.0071
# x:   [8.65677769e+03 1.25187525e+03 5.07483671e+00 5.07483671e+00
#  5.07483671e+00 5.07483671e+00 5.07483671e+00 5.07483671e+00
#  5.07483671e+00 5.07483671e+00 5.07483671e+00 5.07483671e+00
#  5.07483671e+00 5.07483671e+00 5.07483671e+00 5.07483671e+00
#  5.07483671e+00 5.07483671e+00 5.07483671e+00 5.07483671e+00]
# hello, value =  9902.05710188326
# Optimize a model with 1 rows, 20 columns and 20 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e+00, 1e+04]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 1 rows and 20 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.3636338e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds
# Optimal objective -1.363633833e-01
#  -> LP optimal, value = -0.136363
#
# deltasol: [ 1343.22231089 -1251.87525011    -5.07483671    -5.07483671
#     -5.07483671    -5.07483671    -5.07483671    -5.07483671
#     -5.07483671    -5.07483671    -5.07483671    -5.07483671
#     -5.07483671    -5.07483671    -5.07483671    -5.07483671
#     -5.07483671    -5.07483671    -5.07483671    -5.07483671]
# step_size: 0.043000000000000003
# x:   [8.71453625e+03 1.19804461e+03 4.85661873e+00 4.85661873e+00
#  4.85661873e+00 4.85661873e+00 4.85661873e+00 4.85661873e+00
#  4.85661873e+00 4.85661873e+00 4.85661873e+00 4.85661873e+00
#  4.85661873e+00 4.85661873e+00 4.85661873e+00 4.85661873e+00
#  4.85661873e+00 4.85661873e+00 4.85661873e+00 4.85661873e+00]
# hello, value =  9902.06004950871
# Optimize a model with 1 rows, 20 columns and 20 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e+00, 1e+04]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 1 rows and 20 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -8.5329248e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds
# Optimal objective -8.532924792e-01
#  -> LP optimal, value = -0.853292
#
# deltasol: [-8.71453625e+03  8.80195539e+03 -4.85661873e+00 -4.85661873e+00
#  -4.85661873e+00 -4.85661873e+00 -4.85661873e+00 -4.85661873e+00
#  -4.85661873e+00 -4.85661873e+00 -4.85661873e+00 -4.85661873e+00
#  -4.85661873e+00 -4.85661873e+00 -4.85661873e+00 -4.85661873e+00
#  -4.85661873e+00 -4.85661873e+00 -4.85661873e+00 -4.85661873e+00]
# step_size: 0.0063
# x:   [8.65963467e+03 1.25349693e+03 4.82602203e+00 4.82602203e+00
#  4.82602203e+00 4.82602203e+00 4.82602203e+00 4.82602203e+00
#  4.82602203e+00 4.82602203e+00 4.82602203e+00 4.82602203e+00
#  4.82602203e+00 4.82602203e+00 4.82602203e+00 4.82602203e+00
#  4.82602203e+00 4.82602203e+00 4.82602203e+00 4.82602203e+00]
# hello, value =  9902.062724336103
# Optimize a model with 1 rows, 20 columns and 20 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e+00, 1e+04]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 1 rows and 20 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.2145628e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds
# Optimal objective -1.214562768e-01
#  -> LP optimal, value = -0.121456
#
# deltasol: [ 1340.36532989 -1253.49693329    -4.82602203    -4.82602203
#     -4.82602203    -4.82602203    -4.82602203    -4.82602203
#     -4.82602203    -4.82602203    -4.82602203    -4.82602203
#     -4.82602203    -4.82602203    -4.82602203    -4.82602203
#     -4.82602203    -4.82602203    -4.82602203    -4.82602203]
# step_size: 0.0385
# x:   [8.71123874e+03 1.20523730e+03 4.64022019e+00 4.64022019e+00
#  4.64022019e+00 4.64022019e+00 4.64022019e+00 4.64022019e+00
#  4.64022019e+00 4.64022019e+00 4.64022019e+00 4.64022019e+00
#  4.64022019e+00 4.64022019e+00 4.64022019e+00 4.64022019e+00
#  4.64022019e+00 4.64022019e+00 4.64022019e+00 4.64022019e+00]
# hello, value =  9902.065074795179
# Optimize a model with 1 rows, 20 columns and 20 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e+00, 1e+04]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 1 rows and 20 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -7.6826528e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds
# Optimal objective -7.682652766e-01
#  -> LP optimal, value = -0.768265
#
# deltasol: [-8.71123874e+03  8.79476270e+03 -4.64022019e+00 -4.64022019e+00
#  -4.64022019e+00 -4.64022019e+00 -4.64022019e+00 -4.64022019e+00
#  -4.64022019e+00 -4.64022019e+00 -4.64022019e+00 -4.64022019e+00
#  -4.64022019e+00 -4.64022019e+00 -4.64022019e+00 -4.64022019e+00
#  -4.64022019e+00 -4.64022019e+00 -4.64022019e+00 -4.64022019e+00]
# step_size: 0.0057
# x:   [8.66158467e+03 1.25536745e+03 4.61377093e+00 4.61377093e+00
#  4.61377093e+00 4.61377093e+00 4.61377093e+00 4.61377093e+00
#  4.61377093e+00 4.61377093e+00 4.61377093e+00 4.61377093e+00
#  4.61377093e+00 4.61377093e+00 4.61377093e+00 4.61377093e+00
#  4.61377093e+00 4.61377093e+00 4.61377093e+00 4.61377093e+00]
# hello, value =  9902.067248228657
# Optimize a model with 1 rows, 20 columns and 20 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e+00, 1e+04]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 1 rows and 20 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.1025575e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds
# Optimal objective -1.102557517e-01
#  -> LP optimal, value = -0.110256
#
# deltasol: [ 1338.41532548 -1255.36744874    -4.61377093    -4.61377093
#     -4.61377093    -4.61377093    -4.61377093    -4.61377093
#     -4.61377093    -4.61377093    -4.61377093    -4.61377093
#     -4.61377093    -4.61377093    -4.61377093    -4.61377093
#     -4.61377093    -4.61377093    -4.61377093    -4.61377093]
# step_size: 0.0351
# x:   [8.70856305e+03 1.21130405e+03 4.45182757e+00 4.45182757e+00
#  4.45182757e+00 4.45182757e+00 4.45182757e+00 4.45182757e+00
#  4.45182757e+00 4.45182757e+00 4.45182757e+00 4.45182757e+00
#  4.45182757e+00 4.45182757e+00 4.45182757e+00 4.45182757e+00
#  4.45182757e+00 4.45182757e+00 4.45182757e+00 4.45182757e+00]
# hello, value =  9902.06919246182
# Optimize a model with 1 rows, 20 columns and 20 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [4e+00, 1e+04]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 1 rows and 20 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -6.9774845e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds
# Optimal objective -6.977484520e-01
#  -> LP optimal, value = -0.697748
#
# deltasol: [-8.70856305e+03  8.78869595e+03 -4.45182757e+00 -4.45182757e+00
#  -4.45182757e+00 -4.45182757e+00 -4.45182757e+00 -4.45182757e+00
#  -4.45182757e+00 -4.45182757e+00 -4.45182757e+00 -4.45182757e+00
#  -4.45182757e+00 -4.45182757e+00 -4.45182757e+00 -4.45182757e+00
#  -4.45182757e+00 -4.45182757e+00 -4.45182757e+00 -4.45182757e+00]
# step_size: 0.005200000000000001
# x:   [8.66327852e+03 1.25700527e+03 4.42867807e+00 4.42867807e+00
#  4.42867807e+00 4.42867807e+00 4.42867807e+00 4.42867807e+00
#  4.42867807e+00 4.42867807e+00 4.42867807e+00 4.42867807e+00
#  4.42867807e+00 4.42867807e+00 4.42867807e+00 4.42867807e+00
#  4.42867807e+00 4.42867807e+00 4.42867807e+00 4.42867807e+00]
# hello, value =  9902.070988686899
# Optimize a model with 1 rows, 20 columns and 20 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [4e+00, 1e+04]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 1 rows and 20 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.0080915e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds
# Optimal objective -1.008091537e-01
#  -> LP optimal, value = -0.100809
#
# deltasol: [ 1336.72147543 -1257.00527022    -4.42867807    -4.42867807
#     -4.42867807    -4.42867807    -4.42867807    -4.42867807
#     -4.42867807    -4.42867807    -4.42867807    -4.42867807
#     -4.42867807    -4.42867807    -4.42867807    -4.42867807
#     -4.42867807    -4.42867807    -4.42867807    -4.42867807]
# step_size: 0.0322
# x:   [8.70632096e+03 1.21652970e+03 4.28607463e+00 4.28607463e+00
#  4.28607463e+00 4.28607463e+00 4.28607463e+00 4.28607463e+00
#  4.28607463e+00 4.28607463e+00 4.28607463e+00 4.28607463e+00
#  4.28607463e+00 4.28607463e+00 4.28607463e+00 4.28607463e+00
#  4.28607463e+00 4.28607463e+00 4.28607463e+00 4.28607463e+00]
# hello, value =  9902.072619263357
# Optimize a model with 1 rows, 20 columns and 20 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [4e+00, 1e+04]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 1 rows and 20 columns
# Presolve time: 0.07s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -6.3779567e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.13 seconds
# Optimal objective -6.377956712e-01
#  -> LP optimal, value = -0.637796
#
# deltasol: [-8.70632096e+03  8.78347030e+03 -4.28607463e+00 -4.28607463e+00
#  -4.28607463e+00 -4.28607463e+00 -4.28607463e+00 -4.28607463e+00
#  -4.28607463e+00 -4.28607463e+00 -4.28607463e+00 -4.28607463e+00
#  -4.28607463e+00 -4.28607463e+00 -4.28607463e+00 -4.28607463e+00
#  -4.28607463e+00 -4.28607463e+00 -4.28607463e+00 -4.28607463e+00]
# step_size: 0.0047
# x:   [8.66540125e+03 1.25781201e+03 4.26593008e+00 4.26593008e+00
#  4.26593008e+00 4.26593008e+00 4.26593008e+00 4.26593008e+00
#  4.26593008e+00 4.26593008e+00 4.26593008e+00 4.26593008e+00
#  4.26593008e+00 4.26593008e+00 4.26593008e+00 4.26593008e+00
#  4.26593008e+00 4.26593008e+00 4.26593008e+00 4.26593008e+00]
# hello, value =  9902.074122577114
# Optimize a model with 1 rows, 20 columns and 20 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [4e+00, 1e+04]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 1 rows and 20 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -9.1291402e-02   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds
# Optimal objective -9.129140203e-02
#  -> LP optimal, value = -0.0912914
#
# deltasol: [ 1334.59875241 -1257.81201093    -4.26593008    -4.26593008
#     -4.26593008    -4.26593008    -4.26593008    -4.26593008
#     -4.26593008    -4.26593008    -4.26593008    -4.26593008
#     -4.26593008    -4.26593008    -4.26593008    -4.26593008
#     -4.26593008    -4.26593008    -4.26593008    -4.26593008]
# step_size: 0.029300000000000003
# x:   [8.70450499e+03 1.22095812e+03 4.14093833e+00 4.14093833e+00
#  4.14093833e+00 4.14093833e+00 4.14093833e+00 4.14093833e+00
#  4.14093833e+00 4.14093833e+00 4.14093833e+00 4.14093833e+00
#  4.14093833e+00 4.14093833e+00 4.14093833e+00 4.14093833e+00
#  4.14093833e+00 4.14093833e+00 4.14093833e+00 4.14093833e+00]
# hello, value =  9902.075464504596
# Optimize a model with 1 rows, 20 columns and 20 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [4e+00, 1e+04]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 1 rows and 20 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -5.8785588e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds
# Optimal objective -5.878558810e-01
#  -> LP optimal, value = -0.587856
#
# deltasol: [-8.70450499e+03  8.77904188e+03 -4.14093833e+00 -4.14093833e+00
#  -4.14093833e+00 -4.14093833e+00 -4.14093833e+00 -4.14093833e+00
#  -4.14093833e+00 -4.14093833e+00 -4.14093833e+00 -4.14093833e+00
#  -4.14093833e+00 -4.14093833e+00 -4.14093833e+00 -4.14093833e+00
#  -4.14093833e+00 -4.14093833e+00 -4.14093833e+00 -4.14093833e+00]
# step_size: 0.0044
# x:   [8.66620517e+03 1.25958590e+03 4.12271820e+00 4.12271820e+00
#  4.12271820e+00 4.12271820e+00 4.12271820e+00 4.12271820e+00
#  4.12271820e+00 4.12271820e+00 4.12271820e+00 4.12271820e+00
#  4.12271820e+00 4.12271820e+00 4.12271820e+00 4.12271820e+00
#  4.12271820e+00 4.12271820e+00 4.12271820e+00 4.12271820e+00]
# hello, value =  9902.076743345631
# Optimize a model with 1 rows, 20 columns and 20 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [4e+00, 1e+04]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 1 rows and 20 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -8.5545132e-02   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds
# Optimal objective -8.554513211e-02
#  -> LP optimal, value = -0.0855451
#
# deltasol: [ 1333.79483093 -1259.58590328    -4.1227182     -4.1227182
#     -4.1227182     -4.1227182     -4.1227182     -4.1227182
#     -4.1227182     -4.1227182     -4.1227182     -4.1227182
#     -4.1227182     -4.1227182     -4.1227182     -4.1227182
#     -4.1227182     -4.1227182     -4.1227182     -4.1227182 ]
# step_size: 0.0275
# x:   [8.70288453e+03 1.22494729e+03 4.00934345e+00 4.00934345e+00
#  4.00934345e+00 4.00934345e+00 4.00934345e+00 4.00934345e+00
#  4.00934345e+00 4.00934345e+00 4.00934345e+00 4.00934345e+00
#  4.00934345e+00 4.00934345e+00 4.00934345e+00 4.00934345e+00
#  4.00934345e+00 4.00934345e+00 4.00934345e+00 4.00934345e+00]
# hello, value =  9902.077923801739
# Optimize a model with 1 rows, 20 columns and 20 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [4e+00, 1e+04]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 1 rows and 20 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -5.4318483e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds
# Optimal objective -5.431848296e-01
#  -> LP optimal, value = -0.543185
#
# deltasol: [-8.70288453e+03  8.77505271e+03 -4.00934345e+00 -4.00934345e+00
#  -4.00934345e+00 -4.00934345e+00 -4.00934345e+00 -4.00934345e+00
#  -4.00934345e+00 -4.00934345e+00 -4.00934345e+00 -4.00934345e+00
#  -4.00934345e+00 -4.00934345e+00 -4.00934345e+00 -4.00934345e+00
#  -4.00934345e+00 -4.00934345e+00 -4.00934345e+00 -4.00934345e+00]
# step_size: 0.004
# x:   [8.66807299e+03 1.26004750e+03 3.99330608e+00 3.99330608e+00
#  3.99330608e+00 3.99330608e+00 3.99330608e+00 3.99330608e+00
#  3.99330608e+00 3.99330608e+00 3.99330608e+00 3.99330608e+00
#  3.99330608e+00 3.99330608e+00 3.99330608e+00 3.99330608e+00
#  3.99330608e+00 3.99330608e+00 3.99330608e+00 3.99330608e+00]
# hello, value =  9902.079017006146
# Optimize a model with 1 rows, 20 columns and 20 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [4e+00, 1e+04]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 1 rows and 20 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -7.7892777e-02   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds
# Optimal objective -7.789277654e-02
#  -> LP optimal, value = -0.0778928
#
# deltasol: [ 1331.92701118 -1260.04750178    -3.99330608    -3.99330608
#     -3.99330608    -3.99330608    -3.99330608    -3.99330608
#     -3.99330608    -3.99330608    -3.99330608    -3.99330608
#     -3.99330608    -3.99330608    -3.99330608    -3.99330608
#     -3.99330608    -3.99330608    -3.99330608    -3.99330608]
# step_size: 0.0251
# x:   [8.70150436e+03 1.22842031e+03 3.89307410e+00 3.89307410e+00
#  3.89307410e+00 3.89307410e+00 3.89307410e+00 3.89307410e+00
#  3.89307410e+00 3.89307410e+00 3.89307410e+00 3.89307410e+00
#  3.89307410e+00 3.89307410e+00 3.89307410e+00 3.89307410e+00
#  3.89307410e+00 3.89307410e+00 3.89307410e+00 3.89307410e+00]
# hello, value =  9902.079998601354
# Optimize a model with 1 rows, 20 columns and 20 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [4e+00, 1e+04]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 1 rows and 20 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -5.0468073e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds
# Optimal objective -5.046807291e-01
#  -> LP optimal, value = -0.504681
#
# deltasol: [-8.70150436e+03  8.77157969e+03 -3.89307410e+00 -3.89307410e+00
#  -3.89307410e+00 -3.89307410e+00 -3.89307410e+00 -3.89307410e+00
#  -3.89307410e+00 -3.89307410e+00 -3.89307410e+00 -3.89307410e+00
#  -3.89307410e+00 -3.89307410e+00 -3.89307410e+00 -3.89307410e+00
#  -3.89307410e+00 -3.89307410e+00 -3.89307410e+00 -3.89307410e+00]
# step_size: 0.0038
# x:   [8.66843864e+03 1.26175231e+03 3.87828041e+00 3.87828041e+00
#  3.87828041e+00 3.87828041e+00 3.87828041e+00 3.87828041e+00
#  3.87828041e+00 3.87828041e+00 3.87828041e+00 3.87828041e+00
#  3.87828041e+00 3.87828041e+00 3.87828041e+00 3.87828041e+00
#  3.87828041e+00 3.87828041e+00 3.87828041e+00 3.87828041e+00]
# hello, value =  9902.080943260406
# Optimize a model with 1 rows, 20 columns and 20 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [4e+00, 1e+04]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 1 rows and 20 columns
# Presolve time: 0.09s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -7.4183006e-02   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.13 seconds
# Optimal objective -7.418300644e-02
#  -> LP optimal, value = -0.074183
#
# deltasol: [ 1331.56135976 -1261.75231231    -3.87828041    -3.87828041
#     -3.87828041    -3.87828041    -3.87828041    -3.87828041
#     -3.87828041    -3.87828041    -3.87828041    -3.87828041
#     -3.87828041    -3.87828041    -3.87828041    -3.87828041
#     -3.87828041    -3.87828041    -3.87828041    -3.87828041]
# step_size: 0.024
# x:   [8.70039611e+03 1.23147026e+03 3.78520168e+00 3.78520168e+00
#  3.78520168e+00 3.78520168e+00 3.78520168e+00 3.78520168e+00
#  3.78520168e+00 3.78520168e+00 3.78520168e+00 3.78520168e+00
#  3.78520168e+00 3.78520168e+00 3.78520168e+00 3.78520168e+00
#  3.78520168e+00 3.78520168e+00 3.78520168e+00 3.78520168e+00]
# hello, value =  9902.081834543995
# Optimize a model with 1 rows, 20 columns and 20 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [4e+00, 1e+04]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 1 rows and 20 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -4.7177057e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds
# Optimal objective -4.717705682e-01
#  -> LP optimal, value = -0.471771
#
# deltasol: [-8.70039611e+03  8.76852974e+03 -3.78520168e+00 -3.78520168e+00
#  -3.78520168e+00 -3.78520168e+00 -3.78520168e+00 -3.78520168e+00
#  -3.78520168e+00 -3.78520168e+00 -3.78520168e+00 -3.78520168e+00
#  -3.78520168e+00 -3.78520168e+00 -3.78520168e+00 -3.78520168e+00
#  -3.78520168e+00 -3.78520168e+00 -3.78520168e+00 -3.78520168e+00]
# step_size: 0.0035
# x:   [8.66994473e+03 1.26216011e+03 3.77195348e+00 3.77195348e+00
#  3.77195348e+00 3.77195348e+00 3.77195348e+00 3.77195348e+00
#  3.77195348e+00 3.77195348e+00 3.77195348e+00 3.77195348e+00
#  3.77195348e+00 3.77195348e+00 3.77195348e+00 3.77195348e+00
#  3.77195348e+00 3.77195348e+00 3.77195348e+00 3.77195348e+00]
# hello, value =  9902.082660874696
# Optimize a model with 1 rows, 20 columns and 20 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [4e+00, 1e+04]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 1 rows and 20 columns
# Presolve time: 0.04s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -6.8185384e-02   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.07 seconds
# Optimal objective -6.818538383e-02
#  -> LP optimal, value = -0.0681854
#
# deltasol: [ 1330.05527352 -1262.16011091    -3.77195348    -3.77195348
#     -3.77195348    -3.77195348    -3.77195348    -3.77195348
#     -3.77195348    -3.77195348    -3.77195348    -3.77195348
#     -3.77195348    -3.77195348    -3.77195348    -3.77195348
#     -3.77195348    -3.77195348    -3.77195348    -3.77195348]
# step_size: 0.0221
# x:   [8.69933895e+03 1.23426637e+03 3.68859331e+00 3.68859331e+00
#  3.68859331e+00 3.68859331e+00 3.68859331e+00 3.68859331e+00
#  3.68859331e+00 3.68859331e+00 3.68859331e+00 3.68859331e+00
#  3.68859331e+00 3.68859331e+00 3.68859331e+00 3.68859331e+00
#  3.68859331e+00 3.68859331e+00 3.68859331e+00 3.68859331e+00]
# hello, value =  9902.083415634337
# Optimize a model with 1 rows, 20 columns and 20 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [4e+00, 1e+04]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 1 rows and 20 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -4.4139942e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds
# Optimal objective -4.413994193e-01
#  -> LP optimal, value = -0.441399
#
# deltasol: [-8.69933895e+03  8.76573363e+03 -3.68859331e+00 -3.68859331e+00
#  -3.68859331e+00 -3.68859331e+00 -3.68859331e+00 -3.68859331e+00
#  -3.68859331e+00 -3.68859331e+00 -3.68859331e+00 -3.68859331e+00
#  -3.68859331e+00 -3.68859331e+00 -3.68859331e+00 -3.68859331e+00
#  -3.68859331e+00 -3.68859331e+00 -3.68859331e+00 -3.68859331e+00]
# step_size: 0.0033
# x:   [8.67063113e+03 1.26319329e+03 3.67642095e+00 3.67642095e+00
#  3.67642095e+00 3.67642095e+00 3.67642095e+00 3.67642095e+00
#  3.67642095e+00 3.67642095e+00 3.67642095e+00 3.67642095e+00
#  3.67642095e+00 3.67642095e+00 3.67642095e+00 3.67642095e+00
#  3.67642095e+00 3.67642095e+00 3.67642095e+00 3.67642095e+00]
# hello, value =  9902.084139604198
# Optimize a model with 1 rows, 20 columns and 20 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [4e+00, 1e+04]
#   RHS range        [0e+00, 0e+00]
# Presolve removed 1 rows and 20 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -6.4412997e-02   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds
# Optimal objective -6.441299741e-02
#  -> LP optimal, value = -0.064413
#
# deltasol: [ 1329.3688705  -1263.19329343    -3.67642095    -3.67642095
#     -3.67642095    -3.67642095    -3.67642095    -3.67642095
#     -3.67642095    -3.67642095    -3.67642095    -3.67642095
#     -3.67642095    -3.67642095    -3.67642095    -3.67642095
#     -3.67642095    -3.67642095    -3.67642095    -3.67642095]
